# %% [markdown]
# <a href="https://colab.research.google.com/github/eridannagarmashova/BTE-320/blob/main/BTE_320_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# Test

# %%
x = 2
